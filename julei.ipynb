# %%
import anndata as ad
import scanpy as sc
import umap
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad("D:\\新建文件夹 (7)\\m_ako_part1")
adata_subset = adata[:1000, :1000].copy()

# %%
sc.pp.normalize_total(adata_subset, target_sum=1e4)
sc.pp.log1p(adata_subset)

# %%
sc.pp.pca(adata_subset, n_comps=50)

# %%
sc.pp.neighbors(adata_subset)
sc.tl.umap(adata_subset)

# %%
sc.tl.leiden(adata_subset)
# Out:
# C:\Users\86156\AppData\Local\Temp\ipykernel_8508\118113768.py:1: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata_subset)

# %%
sc.pl.umap(adata_subset, color=['leiden'], legend_loc='on data', title='UMAP clustering')
plt.show()
